# %%
# %matplotlib inline
import os, numpy as np, h5py, matplotlib.pyplot as plt
import math
import pandas as pd

import ase
import pyiron
from pyiron import Project, ase_to_pyiron
from ase.io import read,write
import spglib

from molmod.units import *
from molmod.constants import *

import tarfile
import pathlib
import sys

from ase import Atoms
from numpy import linalg as LA
from scipy.spatial.transform import Rotation as R

# %%
class FAmolecule():
    
    def __init__(self, at_c):
        self.atomlst = [at_c]
        self.at_c = at_c
        self.CoM = 0.0
    
    def add_atom(self,at):
        self.atomlst.append(at)
    
    def change_CoM(self):
        self.CoM = 0.0
        tot_mass = 0.0
        for at in self.atomlst:
            tot_mass +=at.mass 
            self.CoM += at.position*at.mass 
        self.CoM /= tot_mass 
        
    def random_rotation_FA(self):
        trans_vec = self.CoM
        rot_mat =  R.random().as_matrix()
        for at in self.atomlst:
            at.position -= trans_vec
            at.position = np.dot(rot_mat, at.position)
            at.position += trans_vec
    
def my_distance_func(at1, at2, cell):
    inv_cell = LA.inv(cell)
    dir_at1 = np.dot(at1.position,inv_cell)
    dir_at2 = np.dot(at2.position,inv_cell)
    dir_at2 -=np.around(dir_at2 - dir_at1)
    new_pos2 = np.dot(dir_at2,cell)
    return LA.norm(at1.position - new_pos2), new_pos2

def check_dist_FA(FAmol, atoms):
    for atFA in FAmol.atomlst:
        for at in atoms:
            dist = my_distance_func(atFA, at, atoms.cell)[0]
            if dist < 2.0:
                return False
    return True
    
def Get_FAmol_lst(atoms):
    FAmol_lst = []
    for at in atoms:
        if at.symbol == 'C':
            FAmol_lst.append(FAmolecule(at))
    for at in atoms:
        flag = False
        while at.symbol == 'N' and flag == False:
            for FAmol in FAmol_lst:
                dist, new_pos = my_distance_func(FAmol.at_c, at, atoms.cell)
                if dist < 2:
                    if dist >1.7:
                        print("long distance between C and N: " + str(dist))
                    at.position = new_pos
                    FAmol.add_atom(at)
                    flag = True
    for at in atoms:
        flag = False
        while at.symbol == 'H' and flag == False:
            for FAmol in FAmol_lst:
                for atFA in FAmol.atomlst:
                    if atFA.symbol != 'H':
                        dist, new_pos = my_distance_func(atFA, at, atoms.cell)
                        if dist < 1.56:
                            at.position = new_pos
                            FAmol.add_atom(at)
                            flag = True
    return FAmol_lst

def Get_new_FArot_atoms(atoms):
    
    atoms_c = atoms.copy()
    atoms_new = Atoms(cell=atoms_c.cell, pbc = True)
    for at in atoms_c:
        if at.symbol == 'Pb' or at.symbol == 'I':
            atoms_new.append(at)
    FAmol_lst = Get_FAmol_lst(atoms_c)
    
    for FAmol in FAmol_lst:
        assert len(FAmol.atomlst) == 8
        FAmol.change_CoM()
        FAmol.random_rotation_FA()
        attempt = 0
        threshold_attempts = 100
        while check_dist_FA(FAmol, atoms_new) == False and attempt < threshold_attempts:
            FAmol.random_rotation_FA() 
            attempt +=1
        if attempt > 0:
            print(attempt)
        if attempt == threshold_attempts:
            print("performed " + str(attempt) + " rotations for one molecule, restart again")
            return False
        for at in FAmol.atomlst:
            atoms_new.append(at)
            
    return atoms_new

# %%
"""
phase_dct = {"gamma":15500, "Csdelta":15550, "FAdelta":15600} #
for phase, vol_start in {"FAdelta":15600}.items(): #phase_dct.items():
    print("    "+phase)
    for vol in np.arange(0,3151,150):
        print("  " + str(int(vol+vol_start)))
        name_file = "vol_"+str(int(vol+vol_start))+".xyz"
        atoms = read(phase + "/"+ name_file)
        atoms_new = Get_new_FArot_atoms(atoms)
        while atoms_new == False:
            print("restarting again:")
            atoms_new = Get_new_FArot_atoms(atoms)

        write("RotatedMA/" + phase + "/" + name_file, atoms_new, format="extxyz")
"""        
phase_dct = {"gamma":15600, "Csdelta":15650, "FAdelta":15700} #
for phase, vol_start in {"FAdelta":15700}.items(): #phase_dct.items():
    print("    "+phase)
    for vol in np.arange(0,2401,600):
        print("  " + str(int(vol+vol_start)))
        name_file = "vol_"+str(int(vol+vol_start))+".xyz"
        atoms = read(phase + "/ValidationRuns/" + name_file)
        atoms_new = Get_new_FArot_atoms(atoms)
        while atoms_new == False:
            print("restarting again:")
            atoms_new = Get_new_FArot_atoms(atoms)

        write("RotatedMA/" + phase + "/ValidationRuns/" + name_file, atoms_new, format="extxyz")
# Out:
#     FAdelta
#   15700
# long distance between C and N: 1.7620150760111397
# long distance between: 1.8903946727289496
# long distance between: 1.8080658931931068
# long distance between: 1.8864772323242507
# long distance between: 1.9440225934651822
# long distance between: 1.9854824741588857
# long distance between: 1.828884635590304
# long distance between: 1.981842234627038
# long distance between: 1.9246351262859227
# long distance between: 1.92721584495793
# long distance between: 1.8240329172125065
# long distance between: 1.9029909150814572
# long distance between: 1.9925316885377953
# long distance between: 1.9650886091838378
# long distance between: 1.9199006692086091
# long distance between: 1.963893653944306
# long distance between: 1.9010753090737116
# long distance between: 1.8482472269042163
# long distance between: 1.8780812351796792
# long distance between: 1.981013769215545
# long distance between: 1.7694674647743243
# long distance between: 1.7823649586332053
# long distance between: 1.9650319870756336
# long distance between: 1.9688712828292128
# long distance between: 1.8968866881681399
# long distance between: 1.9997045098985333
# long distance between: 1.8950654999959171
# long distance between: 1.7816743115112366
# long distance between: 1.8671514926207247
# long distance between: 1.8186121980515026
# long distance between: 1.9435829841412335
# long distance between: 1.9615638822588073
# long distance between: 1.931604537333195
# long distance between: 1.9995060982206752
# long distance between: 1.9189833420713058
# long distance between: 1.9318715147799956
# long distance between: 1.97156101759772
# long distance between: 1.967715632495987
# long distance between: 1.949463047993161
# long distance between: 1.8469974506311175
# long distance between: 1.915806574186845
# long distance between: 1.9983629929787776
# long distance between: 1.8199361984993256
# long distance between: 1.8739490540202304
# long distance between: 1.9882559654656993
# long distance between: 1.9587825690512386
# long distance between: 1.9280114893278406
# long distance between: 1.9235679402982793
# long distance between: 1.9912592753508136
# long distance between: 1.91317940527664
# long distance between: 1.7529831692031475
# long distance between: 1.9344675440069348
# long distance between: 1.8637897929039775
# long distance between: 1.8429612225478782
# long distance between: 1.9999698342512238
# long distance between: 1.9339107013188745
# long distance between: 1.938683244334703
# long distance between: 1.9180189319640404
# long distance between: 1.9237888878593377
# long distance between: 1.9070736150292462
# long distance between: 1.9657789485463548
# long distance between: 1.8157955903930925
# long distance between: 1.9534480103601355
# long distance between: 1.887507428581395
# long distance between: 1.7647490365011818
# long distance between: 1.8267049163592761
# long distance between: 1.8533730962337445
# long distance between: 1.8523094924417332
# long distance between: 1.931527343640517
# long distance between: 1.8676198495069634
# long distance between: 1.913037634310373
# long distance between: 1.87506083139686
# long distance between: 1.9194395249133405
# long distance between: 1.8614343225034475
# long distance between: 1.965995786826441
# long distance between: 1.8490541983861066
# long distance between: 1.8631301974020111
# long distance between: 1.8708251666867688
# long distance between: 1.9851236384842281
# long distance between: 1.9255658133905353
# long distance between: 1.9057190613442037
# long distance between: 1.975889839002282
# long distance between: 1.9598240754761793
# long distance between: 1.9064675040835428
# long distance between: 1.94989898417574
# long distance between: 1.878571523362231
# long distance between: 1.7846692709508925
# long distance between: 1.818171531267483
# long distance between: 1.912076830274795
# 1
#   16300
# long distance between: 1.989072117821951
# long distance between: 1.8966273573297976
# long distance between: 1.95418498639456
# long distance between: 1.9812645445189996
# long distance between: 1.8881878743142497
# long distance between: 1.8689738828917917
# long distance between: 1.97222213801175
# long distance between: 1.9918817645486662
# long distance between: 1.9851782636912572
# long distance between: 1.9778520776703679
# long distance between: 1.9921294017554503
# long distance between: 1.994520110305735
# long distance between: 1.9759311440810654
# long distance between: 1.9687584062390588
# long distance between: 1.9618612936111375
# long distance between: 1.9880445467702639
# long distance between: 1.9922704596915624
# long distance between: 1.974255542389924
# long distance between: 1.91949858032687
# long distance between: 1.8825469140868987
# long distance between: 1.9355584645623998
# long distance between: 1.9980704329194596
# long distance between: 1.9781990005569428
# long distance between: 1.9528603748385567
# long distance between: 1.9325273424800862
# long distance between: 1.9676135487589161
# long distance between: 1.993596692071498
# long distance between: 1.9509673360431221
# long distance between: 1.911714286594129
# long distance between: 1.992265139517086
# long distance between: 1.9925625046428874
# long distance between: 1.978833358980021
# long distance between: 1.997089559651847
# long distance between: 1.9917710345233224
# long distance between: 1.9732451531610304
#   16900
# long distance between: 1.9773698352602362
# long distance between: 1.8946298831491346
# long distance between: 1.9560977736502736
# long distance between: 1.985009805382569
# long distance between: 1.9258907309148992
# long distance between: 1.9960516481219268
# long distance between: 1.981707954857871
# long distance between: 1.9825543601637718
# long distance between: 1.984157174555089
# long distance between: 1.996708834518784
# long distance between: 1.9954828634057276
# long distance between: 1.9110045355865508
# long distance between: 1.9558445945043612
# long distance between: 1.9373099860839613
# long distance between: 1.9256011963403916
# long distance between: 1.9721653141243796
# long distance between: 1.9543462960320146
# long distance between: 1.8934912589788353
# long distance between: 1.9140833645479551
# long distance between: 1.917424184557738
# long distance between: 1.9495574855302928
# long distance between: 1.9104480433800588
# long distance between: 1.9894431727857886
# long distance between: 1.9993480856332735
# long distance between: 1.9397438383595913
# long distance between: 1.991896285680607
# long distance between: 1.9629391136140426
# long distance between: 1.9646298231040769
# long distance between: 1.8856523377159509
# long distance between: 1.8533666456136502
# long distance between: 1.9748708391151275
# long distance between: 1.9039557200212134
# long distance between: 1.988965764503136
# long distance between: 1.9771859935968488
# 1
#   17500
# long distance between C and N: 1.705907091237381
# long distance between C and N: 1.7730254110502535
# long distance between: 1.992098985432452
# long distance between: 1.9999123093182531
# long distance between: 1.9250015955185236
# long distance between: 1.9624922897859034
# long distance between: 1.8435519642434874
# long distance between: 1.9157606506210143
# long distance between: 1.9763415978168986
# long distance between: 1.9587745178738447
# long distance between: 1.8472948479045008
# long distance between: 1.9812007257878428
# long distance between: 1.8611804627860242
# long distance between: 1.9553234407782474
# long distance between: 1.8985691104160047
# long distance between: 1.9868916922596385
# long distance between: 1.9949890578813174
# long distance between: 1.9333362278730903
#   18100
# long distance between C and N: 1.7130611248864052
# long distance between C and N: 1.8252935971852302
# long distance between C and N: 1.7879812237377297
# long distance between C and N: 1.753912139138034
# long distance between C and N: 1.7213610784879048
# long distance between: 1.9943631678191949
# long distance between: 1.9681546641255108
# long distance between: 1.9080070256919912
# long distance between: 1.8874491849424095
# long distance between: 1.980617654320537
# long distance between: 1.9911225357549054
# long distance between: 1.9580983192600743
# long distance between: 1.916951093435087
# long distance between: 1.9353600577431023
# long distance between: 1.986322741974681
# long distance between: 1.9254133246139196
# long distance between: 1.886022364796967
# long distance between: 1.9834306825170285
# long distance between: 1.93409532695032

# %%
phase = "Csdelta"
vol_start = 16200
vol = 150
name_file = "vol_"+str(int(vol+vol_start))+".xyz"
atoms = read(phase + "/" + name_file)
atoms_new = Get_new_FArot_atoms(atoms)
while atoms_new == False:
    print("restarting again:")
    atoms_new = Get_new_FArot_atoms(atoms)
# Out:
# 27
# 1
# 4
# 5
# 1
# 1
# 10
# 2
# 5
# 3
# 1
# 1
# 2
# 96
# 1
# 1
# 1
# 5
# 1
# 1
# 1
# 3

# %%
atoms_tc = atoms

FAmol_lst = Get_FAmol_lst(atoms_tc)

for FAmol in FAmol_lst:
    FAmol_ind_lst = []
    for atFA in FAmol.atomlst:
        FAmol_ind_lst.append(atFA.index)
    for at in atoms_tc:
        if at.index not in FAmol_ind_lst:
            dist = my_distance_func(at, FAmol.at_c, atoms_tc.cell)[0]
            if dist < 5:
                for atFA in FAmol.atomlst:
                    dist = my_distance_func(at, atFA, atoms_tc.cell)[0]
                    if dist < 2.1:
                        print(atFA.index, at.index, at.symbol, dist)

#display(np.sort(atoms_new.get_distances(at.index,np.arange(768),mic=True))[:6])
# Out:
# 76 636 I 2.028370897786893
# 80 148 H 1.8234402309466522
# 144 148 H 2.003770748628222
# 148 80 H 1.8234402309466533
# 148 144 H 2.0037707486282206
